# %% [markdown]
# ---
# title: "Workflow - Country Ecosystem Data Preparation"
# subtitle: "RLE Assessments Workshop"
# author:
#   - name: "Tyler Erickson"
# date: "2026-07-23"
# execute:
#   enabled: false
#   freeze: false
#   cache: false
# format:
#   revealjs:
#     theme: night
#     css: styles.css
#     slide-number: true
#     navigation-mode: vertical
# ---

# %% [markdown]
# ## Presentation Config {visibility="hidden"}
#
# ```{=html}
# <style>
# [data-class-output="small-output"] .cell-output table { font-size: 0.4em; }
# </style>
# ```

# %% [markdown]
# ## Overview
#
# This presentation demonstrates how to prepare ecosystem map data for a country for efficient analysis.
#
# It uses Colombia as an example.

# %% [markdown]
# ## RLE Assessment Tools Overview
#
# ![](images/rle_tools_overview.excalidraw.svg){fig-align="center"}

# %% [markdown]
# ## IDEAM Ecosystems Portal
#
# :::: {.columns}
#
# ::: {.column width="60%"}
# The [IDEAM](https://www.ideam.gov.co/) ecosystems page hosts Colombia's national ecosystem datasets.
#
# From here you can browse and download the **Map of Continental, Coastal and Marine Ecosystems (MEC)** used in this workflow.
#
# The ecosystem data is distributed as a **~2.3 GB zip** file, which contains the data in both Shapefile and Geodatabase formats.
#
# We will make copies in **cloud-optimized formats**, to allow additional workflows.
# :::
#
# ::: {.column width="40%"}
# [![IDEAM ecosystems portal](images/ideam_ecosystem_webpage.png){height="500"}](https://www.ideam.gov.co/ecosistemas){target="_blank" rel="noopener"}
# :::
#
# ::::

# %% [markdown]
# ## Local Processing {.scrollable}

# %% [markdown]
# Click on the [Download the shapefile of the map of ecosystems, continental, coastal and marine or Colombia (MEC)" 1:100,000 2024](https://e436.short.gy/MEcosis2024) which resolves to a login-gated Sharepoint link. Manually download the file to your local computer.
#
# Once it downloads, update the following cell with the actual path.

# %%
#| echo: true
from pathlib import Path

zip_path = Path("~/Downloads/Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024.zip").expanduser()

# %% [markdown]
# Inspect the file to determine the format.

# %%
#| echo: true
# Inspect the file to determine the format.
import zipfile

# Peek inside the zip without extracting it.
with zipfile.ZipFile(zip_path) as zf:
    names = zf.namelist()

print(f"{len(names)} entries in the zip; first few:")
for name in names[:5]:
    print("   ", name)

# Identify the geospatial data sources present (the zip may hold more than one).
gdbs = sorted({n[: n.index(".gdb/") + 4] for n in names if ".gdb/" in n})
shps = sorted(n for n in names if n.lower().endswith(".shp"))

print()
print("File Geodatabases:", gdbs or "none")
print("Shapefiles:       ", shps or "none")
# Out:
# 67 entries in the zip; first few:
#     Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/
#     Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/ECOSISTEMAS_MEC_122024.gdb/
#     Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/ECOSISTEMAS_MEC_122024.gdb/a00000001.freelist
#     Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/ECOSISTEMAS_MEC_122024.gdb/a00000001.gdbindexes
#     Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/ECOSISTEMAS_MEC_122024.gdb/a00000001.gdbtable
#
# File Geodatabases: ['Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/ECOSISTEMAS_MEC_122024.gdb']
# Shapefiles:        ['Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024/SHAPE/e_eccmc_100K_2024.shp']

# %% [markdown]
# The zip file contains the same ecosystem layer in two formats: an [Esri File Geodatabase](https://doc.esri.com/en/arcgis-pro/latest/help/data/geodatabases/manage-file-gdb/file-geodatabases.html) and a [Shapefile](https://doc.arcgis.com/en/arcgis-online/reference/shapefiles.htm).
#
# The Shapefile format can be uploaded into Google Earth Engine
#
# We'll read the Geodatabase formatted data for further processing on a local computer.

# %%
#| echo: true
# Build the GDAL /vsizip/ path pointing at the .gdb directory inside the zip.
gdb_source = (
    f"/vsizip/{zip_path}"
    "/Mapa_Ecosistemas_Continentales_Costeros_Marinos_100K_2024"
    "/ECOSISTEMAS_MEC_122024.gdb"
)

# %% [markdown]
# Read the geodatabase into a GeoDataFrame. (This may take up to 60 seconds.)

# %%
#| echo: true
import geopandas as gpd

gdf = gpd.read_file(gdb_source)
# Out:
# /Users/tylere/Documents/GitHub/RLE-Assessment/rle_workshop/.pixi/envs/default/lib/python3.14/site-packages/pyogrio/raw.py:200: RuntimeWarning: organizePolygons() received a polygon with more than 100 parts. The processing may be really slow.  You can skip the processing by setting METHOD=SKIP, or only make it analyze counter-clock wise parts by setting METHOD=ONLY_CCW if you can assume that the outline of holes is counter-clock wise defined
#   return ogr_read(

# %% [markdown]
# Display the MEC data.

# %%
#| echo: true
gdf
# Out:
#         tipo_ecos     gra_trans                               gran_bioma  \
# 0        Acuatico       Natural  Pedobioma del Zonobioma Humedo Tropical
# 1        Acuatico  Transformado  Pedobioma del Zonobioma Humedo Tropical
# 2        Acuatico       Natural  Pedobioma del Zonobioma Humedo Tropical
# 3        Acuatico  Transformado  Pedobioma del Zonobioma Humedo Tropical
# 4        Acuatico  Transformado  Pedobioma del Zonobioma Humedo Tropical
# ...           ...           ...                                      ...
# 460345  Terrestre       Natural  Pedobioma del Zonobioma Humedo Tropical
# 460346  Terrestre       Natural                Zonobioma Humedo Tropical
# 460347  Terrestre       Natural                Zonobioma Humedo Tropical
# 460348  Terrestre       Natural                Zonobioma Humedo Tropical
# 460349  Terrestre       Natural                Zonobioma Humedo Tropical
#
#                  bioma_preliminar  \
# 0                      Hidrobioma
# 1                       Helobioma
# 2                       Helobioma
# 3                       Helobioma
# 4                       Helobioma
# ...                           ...
# 460345                  Litobioma
# 460346  Zonobioma Humedo Tropical
# 460347  Zonobioma Humedo Tropical
# 460348  Zonobioma Humedo Tropical
# 460349  Zonobioma Humedo Tropical
#
#                                            bioma_IAvH  \
# 0                             Hidrobioma Alto Caquetá
# 1                              Helobioma Alto Caquetá
# 2                              Helobioma Alto Caquetá
# 3                              Helobioma Alto Caquetá
# 4                              Helobioma Alto Caquetá
# ...                                               ...
# 460345                  Litobioma Serranía del Naquén
# 460346  Zonobioma Humedo Tropical Serranía del Naquén
# 460347  Zonobioma Humedo Tropical Serranía del Naquén
# 460348  Zonobioma Humedo Tropical Serranía del Naquén
# 460349  Zonobioma Humedo Tropical Serranía del Naquén
#
#                     ecos_sintesis                    ecos_general  \
# 0                             Rio            Rio de Aguas Blancas
# 1       Transicional Transformado       Transicional Transformado
# 2                          Bosque          Bosque Inundable Basal
# 3       Transicional Transformado       Transicional Transformado
# 4       Transicional Transformado       Transicional Transformado
# ...                           ...                             ...
# 460345          Complejos Rocosos  Complejos Rocosos de Serranias
# 460346                     Bosque             Bosque Basal Humedo
# 460347                     Bosque             Bosque Basal Humedo
# 460348                     Bosque             Bosque Basal Humedo
# 460349                     Bosque             Bosque Basal Humedo
#
#                                                u_sintesis  amb_acuatico  \
# 0       Rio de Aguas Blancas de la zona hidrográfica C...        Lotico
# 1       Transicional Transformado en áreas que predomi...  Transicional
# 2       Bosque Inundable Basal en áreas que predomina ...  Transicional
# 3       Transicional Transformado en áreas que predomi...  Transicional
# 4       Transicional Transformado en áreas que predomi...  Transicional
# ...                                                   ...           ...
# 460345  Complejos Rocosos de Serranias en áreas que pr...          N.A.
# 460346  Bosque Basal Humedo en áreas que predomina Bos...          N.A.
# 460347  Bosque Basal Humedo en áreas que predomina Bos...          N.A.
# 460348  Bosque Basal Humedo en áreas que predomina Bos...          N.A.
# 460349  Bosque Basal Humedo en áreas que predomina Bos...          N.A.
#
#                   subsistema  ... no_anfibio no_aves no_magnoliops  \
# 0           Andino Atlántico  ...        7.0    14.0          15.0
# 1           Andino Atlántico  ...        7.0    14.0          15.0
# 2           Andino Atlántico  ...        7.0    14.0          15.0
# 3           Andino Atlántico  ...        7.0    14.0          15.0
# 4           Andino Atlántico  ...        7.0    14.0          15.0
# ...                      ...  ...        ...     ...           ...
# 460345  Plataformas Antíguas  ...        3.0     5.0           4.0
# 460346  Plataformas Antíguas  ...        3.0     5.0           4.0
# 460347  Plataformas Antíguas  ...        3.0     5.0           4.0
# 460348  Plataformas Antíguas  ...        3.0     5.0           4.0
# 460349  Plataformas Antíguas  ...        3.0     5.0           4.0
#
#        no_mamiferos no_reptiles ruleid override Shape_Length Shape_Area  \
# 0              12.0        10.0     66     None     2.477929   0.003581
# 1              12.0        10.0     75     None     0.028903   0.000023
# 2              12.0        10.0     29     None     0.112034   0.000376
# 3              12.0        10.0     75     None     0.031162   0.000027
# 4              12.0        10.0     75     None     0.038580   0.000024
# ...             ...         ...    ...      ...          ...        ...
# 460345          3.0         2.0     40     None     0.033453   0.000040
# 460346          3.0         2.0     24     None     0.020580   0.000025
# 460347          3.0         2.0     24     None     0.033420   0.000028
# 460348          3.0         2.0     24     None     0.020843   0.000025
# 460349          3.0         2.0     24     None     0.055450   0.000044
#
#                                                  geometry
# 0       MULTIPOLYGON (((-75.91369 0.9763, -75.91345 0....
# 1       MULTIPOLYGON (((-75.52794 0.85907, -75.52701 0...
# 2       MULTIPOLYGON (((-75.51411 0.79744, -75.514 0.7...
# 3       MULTIPOLYGON (((-75.52821 0.87225, -75.5277 0....
# 4       MULTIPOLYGON (((-75.52416 0.79585, -75.52418 0...
# ...                                                   ...
# 460345  MULTIPOLYGON (((-68.21295 1.97073, -68.2133 1....
# 460346  MULTIPOLYGON (((-67.49606 2.17007, -67.4946 2....
# 460347  MULTIPOLYGON (((-67.48783 2.17801, -67.48786 2...
# 460348  MULTIPOLYGON (((-67.34087 1.98014, -67.34116 1...
# 460349  MULTIPOLYGON (((-67.12079 1.59547, -67.1208 1....
#
# [460350 rows x 50 columns]

# %%
#| echo: true
import time

# Summarize the number of unique values of ecosystem columns.
_start = time.perf_counter()
print(f'{gdf["ecos_sintesis"].nunique() = }')
print(f'{gdf["ecos_general"].nunique() = }')
print(f'{gdf["u_sintesis"].nunique() = }')
print(f'Elapsed time: {time.perf_counter() - _start:.4f} seconds')
# Out:
# gdf["ecos_sintesis"].nunique() = 28
# gdf["ecos_general"].nunique() = 87
# gdf["u_sintesis"].nunique() = 14122
# Elapsed time: 0.0503 seconds

# %% [markdown]
# Sort the values by the `ecos_general` field, in order to improve query performance.

# %%
#| echo: true
# Sort by ecosystem so related records are grouped together.
gdf = gdf.sort_values("ecos_general", ignore_index=True)

# %% [markdown]
# Query again, using the sorted records.

# %%
#| echo: true
import time

# Summarize the number of unique values of ecosystem columns.
_start = time.perf_counter()
print(f'{gdf["ecos_sintesis"].nunique() = }')
print(f'{gdf["ecos_general"].nunique() = }')
print(f'{gdf["u_sintesis"].nunique() = }')
print(f'Elapsed time: {time.perf_counter() - _start:.4f} seconds')
# Out:
# gdf["ecos_sintesis"].nunique() = 28
# gdf["ecos_general"].nunique() = 87
# gdf["u_sintesis"].nunique() = 14122
# Elapsed time: 0.0225 seconds

# %%
#| echo: true
# Write the MEC data to a local GeoParquet file. `row_group_size` writes many small
# row groups so a later `filter(ecosystem)` prunes via predicate pushdown instead of
# scanning the whole map. Without it the ~1.7 GB national file lands in a single row
# group that can't be pruned and times out when read whole. The reproducible version
# of this optimization is `pixi run optimize-source` (scripts/optimize_source.py) in
# the assessment template.
gdf.to_parquet(
    "data/ECOSISTEMAS_MEC_122024.parquet", compression="zstd", row_group_size=10_000
)

# %% [markdown]
# ## Create a small development dataset {visibility="hidden"}
#
# Also write a small 5 record dataset, to speed up development/testing.

# %%
gdf.head().to_parquet(
    "data/ECOSISTEMAS_MEC_122024_5records.parquet",
    compression="zstd",
    row_group_size=10_000,
)

# %% [markdown]
# ## Bogota Area Subset
#
# Create a subset of ecoregions around Bogota that will be easier to work with.

# %%
#| echo: true
from shapely.geometry import Polygon

# Area of interest around Bogota (from an Earth Engine polygon, in EPSG:4326 lon/lat).
bogota_aoi = Polygon(
    [
        [-74.27360864858895, 4.898092789377364],
        [-74.27360864858895, 4.29853018346521],
        [-73.3809694884327, 4.29853018346521],
        [-73.3809694884327, 4.898092789377364],
    ]
)

# Reproject the AOI to match the ecosystem data's CRS before the spatial query.
bogota_aoi = gpd.GeoSeries([bogota_aoi], crs="EPSG:4326").to_crs(gdf.crs).iloc[0]

# Subset to the features that intersect the AOI.
gdf_bogata = gdf[gdf.intersects(bogota_aoi)]
gdf_bogata.shape

gdf_bogata.to_parquet(
    "data/ECOSISTEMAS_MEC_122024_bogota_area.parquet",
    compression="zstd",
    row_group_size=10_000,
)

# %% [markdown]
# ## Publish on cloud object storage
#
# :::: {.columns}
#
# ::: {.column width="45%"}
# The ecosystems table was converted to a cloud-native format (parquet) and published on Source Cooperative:
# :::
#
# ::: {.column width="55%"}
# <iframe src="https://source.coop/tyler/colombia-ecosystems-map/ecosistemas" width="100%" height="550" style="border: 1px solid #ccc;"></iframe>
# :::
#
# ::::

# %%
# data_url = 'https://data.source.coop/tyler/colombia-ecosystems-map/ecosistemas/ECOSISTEMAS_MEC_122024.parquet'
# data_url = 'https://data.source.coop/tyler/colombia-ecosystems-map/ecosistemas/ECOSISTEMAS_MEC_122024_5records.parquet'
data_url = 'https://data.source.coop/tyler/colombia-ecosystems-map/ecosistemas/ECOSISTEMAS_MEC_122024_bogota_area.parquet'

# %% [markdown]
# ## Inspect the published dataset {.scrollable}
#
# Read directly from the cloud-hosted GeoParquet and summarize the geometry type and polygon counts.

# %%
#| echo: true
import geopandas as gpd
import fsspec

data = gpd.read_parquet(fsspec.open(data_url).open())

# %%
#| echo: true
data.shape
# Out:
# (4944, 50)

# %%
#| echo: true
data.geometry.crs
# Out:
# <Geographic 2D CRS: EPSG:4686>
# Name: MAGNA-SIRGAS
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Colombia - onshore and offshore. Includes San Andres y Providencia, Malpelo Islands, Roncador Bank, Serrana Bank and Serranilla Bank.
# - bounds: (-84.77, -4.23, -66.87, 15.51)
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
#| echo: true
print(data.geometry.geom_type.value_counts())                       # Polygon vs MultiPolygon
# Out:
# MultiPolygon    4944
# Name: count, dtype: int64

# %%
#| echo: true
data.columns
# Out:
# Index(['tipo_ecos', 'gra_trans', 'gran_bioma', 'bioma_preliminar',
#        'bioma_IAvH', 'ecos_sintesis', 'ecos_general', 'u_sintesis',
#        'amb_acuatico', 'subsistema', 'nom_zh', 'origen', 'tipo_agua', 'clima',
#        'paisaje', 'relieve', 'suelos', 'amb_edafogenetico',
#        'desc_amb_edafogenetico', 'cob', 'sustrato', 'zona', 'temperatura',
#        'salinidad', 'provincia', 'eco_region', 'eco_zona', 'orig_marino',
#        'config_biotica', 'clasif_biotica', 'subclasif_biotica',
#        'grupo_biotico', 'sectores', 'area_ha', 'u_biotica', 'anfibios', 'aves',
#        'magnoliops', 'mamiferos', 'reptiles', 'no_anfibio', 'no_aves',
#        'no_magnoliops', 'no_mamiferos', 'no_reptiles', 'ruleid', 'override',
#        'Shape_Length', 'Shape_Area', 'geometry'],
#       dtype='str')

# %%
#| echo: true
from itables import show

show(data["gran_bioma"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_314990a8_8f50_455e_a496_fc882ede9dc1" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_314990a8_8f50_455e_a496_fc882ede9dc1_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">gran_bioma</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma del Zonobioma Humedo Tropical</td><td style="border:1px solid #ddd;padding:8px">4089</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Azonal del Zonobioma Humedo Tropical</td><td style="border:1px solid #ddd;padding:8px">475</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Pedobioma del Zonobioma Humedo Tropical</td><td style="border:1px solid #ddd;padding:8px">224</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Zonobioma Humedo Tropical</td><td style="border:1px solid #ddd;padding:8px">156</td></tr>
# </tbody></table></div><script>document.getElementById("itables_314990a8_8f50_455e_a496_fc882ede9dc1")?.removeAttribute("hidden");document.getElementById("itables_314990a8_8f50_455e_a496_fc882ede9dc1_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_314990a8_8f50_455e_a496_fc882ede9dc1:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Orobioma del Zonobioma Humedo Tropical\", 4089], [\"Orobioma Azonal del Zonobioma Humedo Tropical\", 475], [\"Pedobioma del Zonobioma Humedo Tropical\", 224], [\"Zonobioma Humedo Tropical\", 156]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>gran_bioma</th>\n      <th></th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
#| echo: true
show(data["bioma_preliminar"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f5c51853_f67f_460f_a441_e7b14e606de5" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_f5c51853_f67f_460f_a441_e7b14e606de5_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">bioma_preliminar</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Andino</td><td style="border:1px solid #ddd;padding:8px">2631</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma de Paramo</td><td style="border:1px solid #ddd;padding:8px">1036</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Azonal Andino</td><td style="border:1px solid #ddd;padding:8px">439</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Subandino</td><td style="border:1px solid #ddd;padding:8px">422</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Helobioma</td><td style="border:1px solid #ddd;padding:8px">168</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Zonobioma Humedo Tropical</td><td style="border:1px solid #ddd;padding:8px">156</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Hidrobioma</td><td style="border:1px solid #ddd;padding:8px">56</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Azonal Subandino</td><td style="border:1px solid #ddd;padding:8px">36</td></tr>
# </tbody></table></div><script>document.getElementById("itables_f5c51853_f67f_460f_a441_e7b14e606de5")?.removeAttribute("hidden");document.getElementById("itables_f5c51853_f67f_460f_a441_e7b14e606de5_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f5c51853_f67f_460f_a441_e7b14e606de5:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Orobioma Andino\", 2631], [\"Orobioma de Paramo\", 1036], [\"Orobioma Azonal Andino\", 439], [\"Orobioma Subandino\", 422], [\"Helobioma\", 168], [\"Zonobioma Humedo Tropical\", 156], [\"Hidrobioma\", 56], [\"Orobioma Azonal Subandino\", 36]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>bioma_preliminar</th>\n      <th></th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
#| echo: true
show(data["ecos_sintesis"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d6169b21_92d8_4c30_bdb6_efb0ff3b5714" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_d6169b21_92d8_4c30_bdb6_efb0ff3b5714_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">ecos_sintesis</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema</td><td style="border:1px solid #ddd;padding:8px">2533</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Paramo</td><td style="border:1px solid #ddd;padding:8px">718</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Bosque</td><td style="border:1px solid #ddd;padding:8px">501</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Vegetacion Secundaria</td><td style="border:1px solid #ddd;padding:8px">479</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Bosque Fragmentado</td><td style="border:1px solid #ddd;padding:8px">221</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Transicional Transformado</td><td style="border:1px solid #ddd;padding:8px">139</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Territorio Artificializado</td><td style="border:1px solid #ddd;padding:8px">104</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Arbustal</td><td style="border:1px solid #ddd;padding:8px">64</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Subxerofitia</td><td style="border:1px solid #ddd;padding:8px">47</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Rio</td><td style="border:1px solid #ddd;padding:8px">40</td></tr>
# </tbody><tfoot><tr><td colspan="2" style="border:none;padding:8px;text-align:center">(7 more rows not shown)</td></tr></tfoot></table></div><script>document.getElementById("itables_d6169b21_92d8_4c30_bdb6_efb0ff3b5714")?.removeAttribute("hidden");document.getElementById("itables_d6169b21_92d8_4c30_bdb6_efb0ff3b5714_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d6169b21_92d8_4c30_bdb6_efb0ff3b5714:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Agroecosistema\", 2533], [\"Paramo\", 718], [\"Bosque\", 501], [\"Vegetacion Secundaria\", 479], [\"Bosque Fragmentado\", 221], [\"Transicional Transformado\", 139], [\"Territorio Artificializado\", 104], [\"Arbustal\", 64], [\"Subxerofitia\", 47], [\"Rio\", 40], [\"Herbazal\", 37], [\"Complejos Rocosos\", 20], [\"Zona Pantanosa\", 19], [\"Cuerpo de Agua Artificial\", 12], [\"Laguna\", 4], [\"Turbera\", 4], [\"Sabana\", 2]]",
#           "layout": {"bottomEnd": "paging", "bottomStart": "info", "topEnd": "search", "topStart": "pageLength"},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>ecos_sintesis</th>\n      <th></th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
#| echo: true
show(data["ecos_general"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4463b3d9_be75_4d14_924e_3cd312055e9a" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_4463b3d9_be75_4d14_924e_3cd312055e9a_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">ecos_general</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema Ganadero</td><td style="border:1px solid #ddd;padding:8px">1054</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Paramo</td><td style="border:1px solid #ddd;padding:8px">718</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema de Mosaico de Cultivos y Pastos</td><td style="border:1px solid #ddd;padding:8px">518</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Vegetación Secundaria</td><td style="border:1px solid #ddd;padding:8px">479</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema de Mosaico de Pastos y Espacios Naturales</td><td style="border:1px solid #ddd;padding:8px">476</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Bosque Andino Humedo</td><td style="border:1px solid #ddd;padding:8px">412</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema de Mosaico de Cultivos, Pastos y Espacios Naturales</td><td style="border:1px solid #ddd;padding:8px">343</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Bosque Fragmentado con Vegetacion Secundaria</td><td style="border:1px solid #ddd;padding:8px">146</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Transicional Transformado</td><td style="border:1px solid #ddd;padding:8px">139</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Territorio Artificializado</td><td style="border:1px solid #ddd;padding:8px">104</td></tr>
# </tbody><tfoot><tr><td colspan="2" style="border:none;padding:8px;text-align:center">(24 more rows not shown)</td></tr></tfoot></table></div><script>document.getElementById("itables_4463b3d9_be75_4d14_924e_3cd312055e9a")?.removeAttribute("hidden");document.getElementById("itables_4463b3d9_be75_4d14_924e_3cd312055e9a_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4463b3d9_be75_4d14_924e_3cd312055e9a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Agroecosistema Ganadero\", 1054], [\"Paramo\", 718], [\"Agroecosistema de Mosaico de Cultivos y Pastos\", 518], [\"Vegetaci\\u00f3n Secundaria\", 479], [\"Agroecosistema de Mosaico de Pastos y Espacios Naturales\", 476], [\"Bosque Andino Humedo\", 412], [\"Agroecosistema de Mosaico de Cultivos, Pastos y Espacios Naturales\", 343], [\"Bosque Fragmentado con Vegetacion Secundaria\", 146], [\"Transicional Transformado\", 139], [\"Territorio Artificializado\", 104], [\"Bosque Fragmentado con Pastos y Cultivos\", 75], [\"Bosque Subandino Humedo\", 71], [\"Agroecosistema Forestal\", 69], [\"Arbustal Andino Humedo\", 60], [\"Subxerofitia Andina\", 44], [\"Rio de Aguas Blancas\", 40], [\"Agroecosistema Papero\", 36], [\"Herbazal Andino Humedo\", 33], [\"Agroecosistema de Cultivos Permanentes\", 30], [\"Complejos Rocosos Andinos\", 20], [\"Zona Pantanosa Andina\", 19], [\"Bosque de Galeria Basal Humedo\", 17], [\"Cuerpo de Agua Artificial\", 12], [\"Agroecosistema de Mosaico de Cultivos y Espacios Naturales\", 4], [\"Arbustal Inundable Andino\", 4], [\"Turbera de Paramo\", 4], [\"Agroecosistema Palmero\", 3], [\"Laguna Tectonica\", 3], [\"Subxerofitia Subandina\", 3], [\"Herbazal Inundable Andino\", 2], [\"Herbazal Subandino Humedo\", 2], [\"Sabana Estacional\", 2], [\"Bosque Basal Humedo\", 1], [\"Laguna Glacial\", 1]]",
#           "layout": {"bottomEnd": "paging", "bottomStart": "info", "topEnd": "search", "topStart": "pageLength"},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>ecos_general</th>\n      <th></th>\n    </tr>\n  </thead></table>",
#           "text_in_header

# %%
#| echo: true
show(data["bioma_IAvH"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5542e617_d0f0_4498_98fd_4753e449f98e" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_5542e617_d0f0_4498_98fd_4753e449f98e_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">bioma_IAvH</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Andino Altoandino Influencia Llanera</td><td style="border:1px solid #ddd;padding:8px">1293</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Andino Altoandino Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">1100</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma de Paramo Altoandino Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">845</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Azonal Andino Altoandino Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">403</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Andino Vertiente Llanera Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">229</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Subandino Vertiente Llanera Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">188</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma de Paramo Altoandino Influencia Llanera</td><td style="border:1px solid #ddd;padding:8px">175</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Helobioma Altoandino Cordillera Oriental</td><td style="border:1px solid #ddd;padding:8px">168</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Orobioma Subandino Piedemonte Orinoquia</td><td style="border:1px solid #ddd;padding:8px">140</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Zonobioma Humedo Tropical Piedemonte Orinoquia</td><td style="border:1px solid #ddd;padding:8px">95</td></tr>
# </tbody><tfoot><tr><td colspan="2" style="border:none;padding:8px;text-align:center">(14 more rows not shown)</td></tr></tfoot></table></div><script>document.getElementById("itables_5542e617_d0f0_4498_98fd_4753e449f98e")?.removeAttribute("hidden");document.getElementById("itables_5542e617_d0f0_4498_98fd_4753e449f98e_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5542e617_d0f0_4498_98fd_4753e449f98e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Orobioma Andino Altoandino Influencia Llanera\", 1293], [\"Orobioma Andino Altoandino Cordillera Oriental\", 1100], [\"Orobioma de Paramo Altoandino Cordillera Oriental\", 845], [\"Orobioma Azonal Andino Altoandino Cordillera Oriental\", 403], [\"Orobioma Andino Vertiente Llanera Cordillera Oriental\", 229], [\"Orobioma Subandino Vertiente Llanera Cordillera Oriental\", 188], [\"Orobioma de Paramo Altoandino Influencia Llanera\", 175], [\"Helobioma Altoandino Cordillera Oriental\", 168], [\"Orobioma Subandino Piedemonte Orinoquia\", 140], [\"Zonobioma Humedo Tropical Piedemonte Orinoquia\", 95], [\"Orobioma Subandino Altoandino Influencia Llanera\", 94], [\"Zonobioma Humedo Tropical Villavicencio\", 59], [\"Orobioma Azonal Andino Altoandino Influencia Llanera\", 36], [\"Orobioma Azonal Subandino Altoandino Influencia Llanera\", 33], [\"Orobioma de Paramo Vertiente Llanera Cordillera Oriental\", 16], [\"Hidrobioma Altoandino Cordillera Oriental\", 16], [\"Hidrobioma Altoandino Influencia Llanera\", 14], [\"Hidrobioma Piedemonte Orinoquia\", 10], [\"Orobioma Andino Piedemonte Orinoquia\", 9], [\"Hidrobioma Vertiente Llanera Cordillera Oriental\", 9], [\"Hidrobioma Villavicencio\", 7], [\"Orobioma Azonal Subandino Altoandino Cordillera Oriental\", 3], [\"Zonobioma Humedo Tropical Vertiente Llanera Cordillera Oriental\", 1], [\"Peinobioma Piedemonte Orinoquia\", 1]]",
#           "layout": {"bottomEnd": "paging", "bottomStart": "info", "topEnd": "search", "topStart": "pageLength"},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr st

# %%
#| echo: true
show(data["u_sintesis"].value_counts().to_frame("count"))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5a4ddadf_9aea_4820_8433_77ab9afd0505" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.0 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_5a4ddadf_9aea_4820_8433_77ab9afd0505_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.0 static preview">ⓘ</a></sup></th>
#       <th style="border:1px solid #ddd;padding:8px">count</th>
#     </tr>
#     <tr>
#       <th style="border:1px solid #ddd;padding:8px">u_sintesis</th>
#       <th style="border:1px solid #ddd;padding:8px"></th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema Ganadero en áreas que predomina Pastos de clima Frio Semihumedo sobre Cuestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente</td><td style="border:1px solid #ddd;padding:8px">82</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Transicional Transformado en áreas que predomina Pastos sobre Plano de inundación en la Zona Hidrográfica Alto Magdalena</td><td style="border:1px solid #ddd;padding:8px">63</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Páramo en áreas que predomina Herbazal Denso de clima Muy frio Humedo sobre Crestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente</td><td style="border:1px solid #ddd;padding:8px">55</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema Ganadero en áreas que predomina Pastos de clima Frio Humedo sobre Crestas y espinazos en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente</td><td style="border:1px solid #ddd;padding:8px">53</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Páramo en áreas que predomina Arbustal Abierto de clima Muy frio Humedo sobre Crestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente</td><td style="border:1px solid #ddd;padding:8px">50</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema Ganadero en áreas que predomina Pastos de clima Frio Humedo sobre Cuestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente</td><td style="border:1px solid #ddd;padding:8px">45</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Páramo en áreas que predomina Herbazal Denso de clima Muy frio Humedo sobre Cumbres andinas en suelos con Temperaturas muy bajas (Piso termico extremadamente frio y subnival) y Pendientes escarpadas o Miscelaneo Rocoso</td><td style="border:1px solid #ddd;padding:8px">42</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Rio de Aguas Blancas de la zona hidrográfica Meta</td><td style="border:1px solid #ddd;padding:8px">38</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema de Mosaico de Pastos y Espacios Naturales en áreas que predomina Mosaico de Pastos y Espacios Naturales de clima Frio Semihumedo sobre Cuestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion m</td><td style="border:1px solid #ddd;padding:8px">37</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Agroecosistema de Mosaico de Cultivos, Pastos y Espacios Naturales en áreas que predomina Mosaico de Cultivos, Pastos y Espacios Naturales de clima Frio Semihumedo sobre Cuestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxi</td><td style="border:1px solid #ddd;padding:8px">34</td></tr>
# </tbody><tfoot><tr><td colspan="2" style="border:none;padding:8px;text-align:center">(918 more rows not shown)</td></tr></tfoot></table></div><script>document.getElementById("itables_5a4ddadf_9aea_4820_8433_77ab9afd0505")?.removeAttribute("hidden");document.getElementById("itables_5a4ddadf_9aea_4820_8433_77ab9afd0505_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5a4ddadf_9aea_4820_8433_77ab9afd0505:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Agroecosistema Ganadero en \\u00e1reas que predomina Pastos de clima Frio Semihumedo sobre Cuestas y crestones en suelos con Materiales de cenizas volcanicas y Condiciones oxidantes y evolucion moderada o incipiente\", 82], [\"Transicional Transforma

# %%
gdf.head()['ecos_general']
# Out:
# 0    Agroecosistema Arrocero
# 1    Agroecosistema Arrocero
# 2    Agroecosistema Arrocero
# 3    Agroecosistema Arrocero
# 4    Agroecosistema Arrocero
# Name: ecos_general, dtype: str

# %% [markdown]
# ## Build Caches
#
# Set the default login for the application.
#
# ```shell
# gcloud auth application-default login
# ```
#
# Build data caches to increase speed and decrease memory use.
#
# ```shell
# pixi run build-caches --project <project>
# ```
